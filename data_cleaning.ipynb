# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
jobs = pd.read_csv('jobs.csv', sep=',', na_values=[''], quotechar='"')

# %%
jobs.columns

# %%
jobs['remote_allowed'] = jobs['remote_allowed'].fillna("No",axis=0)
jobs['remote_allowed'] = jobs['remote_allowed'].replace(1,"Yes")

# %%
jobs['applies'] = jobs['applies'].fillna("0")
jobs['applies'] = jobs['applies'].astype(int)

# %%
jobs['posting_date'] = pd.to_datetime(jobs['original_listed_time'], unit='ms').dt.date
jobs['posting_time'] = pd.to_datetime(jobs['original_listed_time'], unit='ms').dt.time

# %%
jobs.drop('original_listed_time',axis=1, inplace=True)

# %%
jobs['experience_level'] = jobs['formatted_experience_level'].fillna("No-Experience")

# %%
jobs.drop('formatted_experience_level',axis=1, inplace=True)

# %%
counts = jobs['compensation_type'].value_counts()

# %%
counts
# Out:
# compensation_type
# BASE_SALARY    36073
# Name: count, dtype: int64

# %%
jobs.shape
# Out:
# (123849, 19)

# %%
jobs['application_type'] = jobs['application_type'].replace('ComplexOnsiteApply',"Onsite")
jobs['application_type'] = jobs['application_type'].replace('OffsiteApply',"Offsite")
jobs['application_type'] = jobs['application_type'].replace('SimpleOnsiteApply',"Onsite")
jobs['application_type'] = jobs['application_type'].replace('UnknownApply',"Offsite")

# %%
count = jobs['application_type'].value_counts()
count
# Out:
# application_type
# Offsite    84608
# Onsite     39241
# Name: count, dtype: int64

# %%
jobs
# Out:
#                                                     title  max_salary  \
# 0                                   Marketing Coordinator        20.0
# 1                       Mental Health Therapist/Counselor        50.0
# 2                             Assitant Restaurant Manager     65000.0
# 3       Senior Elder Law / Trusts and Estates Associat...    175000.0
# 4                                      Service Technician     80000.0
# ...                                                   ...         ...
# 123844                   Title IX/Investigations Attorney    195000.0
# 123845       Staff Software Engineer, ML Serving Platform         NaN
# 123846               Account Executive, Oregon/Washington         NaN
# 123847                       Business Development Manager         NaN
# 123848                  Marketing Social Media Specialist     75000.0
#
#        pay_period                 location  views  min_salary  \
# 0          HOURLY            Princeton, NJ   20.0        17.0
# 1          HOURLY         Fort Collins, CO    1.0        30.0
# 2          YEARLY           Cincinnati, OH    8.0     45000.0
# 3          YEARLY        New Hyde Park, NY   16.0    140000.0
# 4          YEARLY           Burlington, IA    3.0     60000.0
# ...           ...                      ...    ...         ...
# 123844     YEARLY         Walnut Creek, CA    1.0    120000.0
# 123845        NaN            United States    3.0         NaN
# 123846        NaN              Spokane, WA    3.0         NaN
# 123847        NaN     Texas, United States    4.0         NaN
# 123848     YEARLY  San Juan Capistrano, CA    2.0     70000.0
#
#        formatted_work_type  applies remote_allowed application_type  \
# 0                Full-time        2             No           Onsite
# 1                Full-time        0             No           Onsite
# 2                Full-time        0             No           Onsite
# 3                Full-time        0             No           Onsite
# 4                Full-time        0             No           Onsite
# ...                    ...      ...            ...              ...
# 123844           Full-time        0             No           Onsite
# 123845           Full-time        0            Yes          Offsite
# 123846           Full-time        0            Yes          Offsite
# 123847           Full-time        0            Yes           Onsite
# 123848           Full-time        0             No           Onsite
#
#               expiry   listed_time  work_type currency compensation_type  \
# 0       1.715990e+12  1.713400e+12  FULL_TIME      USD       BASE_SALARY
# 1       1.715450e+12  1.712860e+12  FULL_TIME      USD       BASE_SALARY
# 2       1.715870e+12  1.713280e+12  FULL_TIME      USD       BASE_SALARY
# 3       1.715490e+12  1.712900e+12  FULL_TIME      USD       BASE_SALARY
# 4       1.716040e+12  1.713450e+12  FULL_TIME      USD       BASE_SALARY
# ...              ...           ...        ...      ...               ...
# 123844  1.716160e+12  1.713570e+12  FULL_TIME      USD       BASE_SALARY
# 123845  1.716160e+12  1.713570e+12  FULL_TIME      NaN               NaN
# 123846  1.716160e+12  1.713570e+12  FULL_TIME      NaN               NaN
# 123847  1.716160e+12  1.713570e+12  FULL_TIME      NaN               NaN
# 123848  1.716160e+12  1.713570e+12  FULL_TIME      USD       BASE_SALARY
#
#         normalized_salary posting_date posting_time  experience_level
# 0                 38480.0   2024-04-18     00:26:40     No-Experience
# 1                 83200.0   2024-04-11     18:26:40     No-Experience
# 2                 55000.0   2024-04-16     15:06:40     No-Experience
# 3                157500.0   2024-04-12     05:33:20     No-Experience
# 4                 70000.0   2024-04-18     14:20:00     No-Experience
# ...                   ...          ...          ...               ...
# 123844           157500.0   2024-04-19     23:40:00  Mid-Senior level
# 123845                NaN   2024-04-19     23:40:00  Mid-Senior level
# 123846                NaN   2024-04-19     23:40:00  Mid-Senior level
# 123847                NaN   2024-04-19     23:40:00     No-Experience
# 123848            72500.0   2024-04-19     23:40:00  Mid-Senior level
#
# [123849 rows x 19 columns]
